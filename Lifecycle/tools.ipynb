# %% [markdown]
# # Tools infrastructure landscape
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Parallelism and other speedup techniques
#
# ### Lecture
#
# https://fullstackdeeplearning.com/course/2022/lecture-2-development-infrastructure-and-tooling/

# %% [markdown]
# # Experiment tools
#
# Review of tools for experiment management (TensorBoard, W&B) + searching of NN hyperparameters using W&B Sweep tool.
#
# ### Lab
#
# https://fullstackdeeplearning.com/course/2022/lab-4-experiment-management/
#
# ### Repo
#
# https://github.com/the-full-stack/fsdl-text-recognizer-2022-labs/tree/main/lab04

# %% [markdown]
# # Linters and Testing and Profiling tools
#
# Review of tools for linting, testing and profiling + techniques and adivces how to speed up your NN using Pytorch, TensorBorad and W&B
#
# ### Lecture
#
# https://fullstackdeeplearning.com/course/2022/lecture-3-troubleshooting-and-testing/
#
# ### Lab
#
# https://fullstackdeeplearning.com/course/2022/lab-5-troubleshooting-and-testing/
#
# ### Repo
#
# https://github.com/the-full-stack/fsdl-text-recognizer-2022-labs/tree/main/lab05
